# %% [markdown]
# # Grid Infrastructure Dataset

# %% [markdown]
# ## Inspect

# %%
import pandas as pd
df = pd.read_csv("grid_load_stream_v2.csv")

# %%
print("Shape:")
print(df.shape)
print("Columns:")
print(df.columns.tolist())
print("Data types:")
print(df.dtypes)
print("First 5 rows:")
print(df.head())
# Out:
# Shape:
# (50000, 16)
#
# Columns:
# ['household_id', 'grid_region', 'substation_name', 'feeder_line', 'distribution_zone', 'grid_operator', 'grid_voltage', 'grid_current', 'grid_load_kw', 'transformer_load', 'line_loss_percent', 'load_variation', 'frequency_variation', 'grid_capacity_kw', 'demand_forecast_kw', 'reserve_margin']
#
# Data types:
# household_id             int64
# grid_region             object
# substation_name         object
# feeder_line             object
# distribution_zone       object
# grid_operator           object
# grid_voltage           float64
# grid_current           float64
# grid_load_kw           float64
# transformer_load       float64
# line_loss_percent      float64
# load_variation         float64
# frequency_variation    float64
# grid_capacity_kw       float64
# demand_forecast_kw     float64
# reserve_margin         float64
# dtype: object
#
# First 5 rows:
#    household_id grid_region substation_name feeder_line distribution_zone  \
# ...

# %% [markdown]
# ## Check Missing Values & Duplicate Rows

# %%
print("Missing values:")
print(df.isnull().sum())
print("Duplicate rows:")
print(df.duplicated().sum())
print("DateTime info (first and last):")
print(df.iloc[0, 0], "to", df.iloc[-1, 0])
# Out:
# Missing values:
# household_id           0
# grid_region            0
# substation_name        0
# feeder_line            0
# distribution_zone      0
# grid_operator          0
# grid_voltage           0
# grid_current           0
# grid_load_kw           0
# transformer_load       0
# line_loss_percent      0
# load_variation         0
# frequency_variation    0
# grid_capacity_kw       0
# demand_forecast_kw     0
# reserve_margin         0
# dtype: int64
#
# Duplicate rows:
# 0
#
# DateTime info (first and last):
# 8270 to 8309

# %%
df.nunique()
# Out:
# household_id            8964
# grid_region                4
# substation_name            3
# feeder_line                3
# distribution_zone          3
# grid_operator              2
# grid_voltage           50000
# grid_current           50000
# grid_load_kw           50000
# transformer_load       50000
# line_loss_percent      50000
# load_variation         50000
# frequency_variation    50000
# grid_capacity_kw       50000
# demand_forecast_kw     50000
# reserve_margin         50000
# dtype: int64

# %%
df.tail()
# Out:
#        household_id grid_region substation_name feeder_line distribution_zone  \
# 49995          8143        East             SS2          F1                Z3
# 49996          9947        East             SS1          F2                Z2
# 49997          5871        West             SS3          F2                Z2
# 49998          4836        East             SS1          F1                Z1
# 49999          8309        East             SS1          F2                Z3
#
#       grid_operator  grid_voltage  grid_current  grid_load_kw  \
# 49995     OperatorB    217.023473     39.641742    135.784876
# 49996     OperatorA    228.425121     35.874631     60.422244
# 49997     OperatorA    214.055114     21.376189    100.888143
# 49998     OperatorA    248.985930     28.348764     92.502482
# 49999     OperatorB    232.018951     18.521542     83.729500
#
#        transformer_load  line_loss_percent  load_variation  \
# 49995        143.669658           1.325210        3.633577
# ...

# %% [markdown]
# ## Understand

# %%
df.describe()
# Out:
#        household_id  grid_voltage  grid_current  grid_load_kw  \
# count  50000.000000  50000.000000  50000.000000  50000.000000
# mean    5494.083720    230.054075     30.008676    105.172566
# std     2601.545347     11.557563     11.553822     54.857285
# min     1000.000000    210.001394     10.000792     10.000738
# 25%     3232.750000    220.027106     19.942269     57.627209
# 50%     5497.000000    230.151534     30.062415    104.980652
# 75%     7746.000000    240.042906     40.023141    152.777235
# max     9999.000000    249.999656     49.999745    199.998382
#
#        transformer_load  line_loss_percent  load_variation  \
# count      50000.000000       50000.000000    50000.000000
# mean          77.317554           5.494157       -0.036673
# std           41.733424           2.601783       11.508397
# min            5.001495           1.000036      -19.999952
# 25%           41.372412           3.253213       -9.989213
# ...

# %%
(df['load_variation'] < 0).sum(), (df['frequency_variation'] < 0).sum()
# Out:
# (np.int64(25083), np.int64(24984))

# %% [markdown]
# ## Final Validation

# %%
df.shape
# Out:
# (50000, 16)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv(r'C:\Users\Royal\Downloads\grid_data_cleaned.csv', index=False)
