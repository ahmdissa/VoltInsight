# %% [markdown]
# # Billing & Tariff Dataset

# %% [markdown]
# ## Inspect

# %%
import pandas as pd
df = pd.read_csv("tariff_metrics_stream_v2.csv")

# %%
print("Shape:")
print(df.shape)
print("Columns:")
print(df.columns.tolist())
print("Data types:")
print(df.dtypes)
print("First 5 rows:")
print(df.head())
# Out:
# Shape:
# (50000, 16)
#
# Columns:
# ['household_id', 'tariff_region', 'tariff_city', 'tariff_plan_type', 'billing_cycle', 'utility_provider', 'unit_rate', 'peak_rate', 'offpeak_rate', 'fixed_charge', 'tax_amount', 'subsidy_amount', 'monthly_bill', 'billing_units', 'late_fee', 'adjustment_amount']
#
# Data types:
# household_id           int64
# tariff_region         object
# tariff_city           object
# tariff_plan_type      object
# billing_cycle         object
# utility_provider      object
# unit_rate            float64
# peak_rate            float64
# offpeak_rate         float64
# fixed_charge         float64
# tax_amount           float64
# subsidy_amount       float64
# monthly_bill         float64
# billing_units        float64
# late_fee             float64
# adjustment_amount    float64
# dtype: object
#
# First 5 rows:
#    household_id tariff_region tariff_city tariff_plan_type billing_cycle  \
# 0          8270         South       Delhi       Industrial       Monthly
# ...

# %% [markdown]
# ## Check Missing Values & Duplicate Rows

# %%
print("Missing values:")
print(df.isnull().sum())
print("Duplicate rows:")
print(df.duplicated().sum())
print("DateTime info (first and last):")
print(df.iloc[0, 0], "to", df.iloc[-1, 0])
# Out:
# Missing values:
# household_id         0
# tariff_region        0
# tariff_city          0
# tariff_plan_type     0
# billing_cycle        0
# utility_provider     0
# unit_rate            0
# peak_rate            0
# offpeak_rate         0
# fixed_charge         0
# tax_amount           0
# subsidy_amount       0
# monthly_bill         0
# billing_units        0
# late_fee             0
# adjustment_amount    0
# dtype: int64
#
# Duplicate rows:
# 0
#
# DateTime info (first and last):
# 8270 to 8309

# %%
df.nunique()
# Out:
# household_id          8964
# tariff_region            4
# tariff_city              4
# tariff_plan_type         3
# billing_cycle            2
# utility_provider         3
# unit_rate            50000
# peak_rate            50000
# offpeak_rate         50000
# fixed_charge         50000
# tax_amount           50000
# subsidy_amount       50000
# monthly_bill         50000
# billing_units        50000
# late_fee             50000
# adjustment_amount    50000
# dtype: int64

# %%
df.tail()
# Out:
#        household_id tariff_region tariff_city tariff_plan_type billing_cycle  \
# 49995          8143          East   Bangalore      Residential       Monthly
# 49996          9947         South       Delhi       Commercial       Monthly
# 49997          5871          West     Chennai       Commercial       Monthly
# 49998          4836          East   Bangalore       Industrial    Bi-Monthly
# 49999          8309         North     Chennai       Industrial    Bi-Monthly
#
#       utility_provider  unit_rate  peak_rate  offpeak_rate  fixed_charge  \
# 49995        ProviderC   3.941989  13.306437      5.163784     88.342653
# 49996        ProviderA   4.723138   8.350411      4.841852    118.899070
# 49997        ProviderA   5.995422  12.484803      4.432297    122.131097
# 49998        ProviderB   9.254497   5.815251      6.764123     55.159859
# 49999        ProviderA   7.370274  10.762484      7.925458    161.132769
#
# ...

# %% [markdown]
# ## Understand

# %%
(df['adjustment_amount'] < 0).sum()
# Out:
# np.int64(25237)

# %%
df['adjustment_amount'].describe()
# Out:
# count    50000.000000
# mean        -0.221611
# std         28.879815
# min        -49.993013
# 25%        -25.254271
# 50%         -0.487129
# 75%         24.801934
# max         49.997623
# Name: adjustment_amount, dtype: float64

# %% [markdown]
# ## Final Validation

# %%
df.describe()
# Out:
#        household_id     unit_rate     peak_rate  offpeak_rate  fixed_charge  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean    5494.083720      6.496065      9.983058      5.006696    124.812261
# std     2601.545347      2.027014      2.883188      1.737810     43.223825
# min     1000.000000      3.000048      5.000160      2.000038     50.004646
# 25%     3232.750000      4.739372      7.482773      3.497771     87.532772
# 50%     5497.000000      6.487517      9.971727      5.009429    124.614044
# 75%     7746.000000      8.258429     12.481605      6.513580    162.073520
# max     9999.000000      9.999985     14.999791      7.999977    199.999433
#
#          tax_amount  subsidy_amount  monthly_bill  billing_units  \
# count  50000.000000    50000.000000  50000.000000   50000.000000
# mean      27.535496       14.992099   1102.468190     325.419801
# std       12.991359        8.659937    519.631882     158.984514
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   household_id       50000 non-null  int64
#  1   tariff_region      50000 non-null  object
#  2   tariff_city        50000 non-null  object
#  3   tariff_plan_type   50000 non-null  object
#  4   billing_cycle      50000 non-null  object
#  5   utility_provider   50000 non-null  object
#  6   unit_rate          50000 non-null  float64
#  7   peak_rate          50000 non-null  float64
#  8   offpeak_rate       50000 non-null  float64
#  9   fixed_charge       50000 non-null  float64
#  10  tax_amount         50000 non-null  float64
#  11  subsidy_amount     50000 non-null  float64
#  12  monthly_bill       50000 non-null  float64
#  13  billing_units      50000 non-null  float64
#  14  late_fee           50000 non-null  float64
# ...

# %%
df.shape
# Out:
# (50000, 16)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv(r'C:\Users\Royal\Downloads\billing_data_cleaned.csv', index=False)
